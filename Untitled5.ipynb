# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\Vita Rabotinskaya\\big_table.xlsx')

# %%
df
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0     1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1     1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2     1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
# 3     1390274421  2023-05-18 16:56:19       1969-10-17   СВН17.10.1969
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# ...          ...                  ...              ...             ...
# 1246  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
# 1247  1637052808  2024-02-26 11:53:10       1989-07-11   ЕУИ11.07.1989
# 1248  1637047529  2024-02-26 11:47:56       1997-05-21   ВЕА01.05.1997
# 1249  1857808898  2024-10-08 10:25:37       1993-12-08   ГТГ08.12.1993
# 1250  1882566725  2024-11-01 13:22:07       1994-08-21   ПСИ21.08.1994
#
#       4. Идентификационный номер участника исследования  \
# 0                                              77046135
# ...

# %%
df2 = pd.DataFrame.from_dict({'a':[1,2], 'b':[3,4]})

# %%
df2
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df2.to_excel('C:\\Users\\Vita Rabotinskaya\\probuu.xlsx')

# %% [markdown]
# информация о файле

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251 entries, 0 to 1250
# Columns: 281 entries, ID to Сколько сигарет (электронных сигарет) участник выкуривает в день?
# dtypes: float64(24), int64(4), object(253)
# memory usage: 2.7+ MB

# %% [markdown]
# размер файла

# %%
df.shape
# Out:
# (1251, 281)

# %% [markdown]
# названия колонок

# %%
df.columns
# Out:
# Index(['ID', 'Время создания', '2. Дата рождения', '3. Код пациента',
#        '4. Идентификационный номер участника исследования',
#        '5. Дата приема участника исследования',
#        '6. Дата подписания информированного согласия', '7. Место рождения',
#        '8. Место рождения (населенный пункт)', '9. Пол',
#        ...
#        '6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / острая интоксикация',
#        '6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / пагубное употребление',
#        '6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / абстинентное состояние',
#        '6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / абстинентное стояние с делирием',
#        '6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / амнестический синдром',
# ...

# %% [markdown]
# типы колонок

# %%
df.dtypes
# Out:
# ID                                                                                                                                             object
# Время создания                                                                                                                                 object
# 2. Дата рождения                                                                                                                               object
# 3. Код пациента                                                                                                                                object
# 4. Идентификационный номер участника исследования                                                                                               int64
#                                                                                                                                                ...
# ...

# %% [markdown]
# только первые

# %%
df.head(3)
# Out:
#            ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0  1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1  1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2  1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
#
#    4. Идентификационный номер участника исследования  \
# 0                                           77046135
# 1                                           77046136
# 2                                           77046137
#
#   5. Дата приема участника исследования  \
# 0                            2023-05-18
# 1                            2023-05-17
# 2                            2023-05-18
#
#   6. Дата подписания информированного согласия         7. Место рождения  \
# 0                                   2023-05-17      24 Красноярский край
# 1                                   2023-05-17  52 Нижегородская область
# 2                                   2023-05-18              77 г. Москва
#
# ...

# %% [markdown]
# только последние

# %%
df.tail(5)
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 1246  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
# 1247  1637052808  2024-02-26 11:53:10       1989-07-11   ЕУИ11.07.1989
# 1248  1637047529  2024-02-26 11:47:56       1997-05-21   ВЕА01.05.1997
# 1249  1857808898  2024-10-08 10:25:37       1993-12-08   ГТГ08.12.1993
# 1250  1882566725  2024-11-01 13:22:07       1994-08-21   ПСИ21.08.1994
#
#       4. Идентификационный номер участника исследования  \
# 1246                                           77047003
# 1247                                           77047005
# 1248                                           77047007
# 1249                                           77047246
# 1250                                           77047333
#
#      5. Дата приема участника исследования  \
# 1246                            2024-02-26
# 1247                            2024-02-26
# 1248                            2024-02-26
# ...

# %% [markdown]
# фильтр данных

# %%
df['Время создания'] #взяли только эту колонку
# Out:
# 0       2023-05-18 12:59:34
# 1       2023-05-17 11:17:08
# 2       2023-05-18 13:48:06
# 3       2023-05-18 16:56:19
# 4       2023-05-18 10:07:04
#                ...
# 1246    2024-02-26 11:58:22
# 1247    2024-02-26 11:53:10
# 1248    2024-02-26 11:47:56
# 1249    2024-10-08 10:25:37
# 1250    2024-11-01 13:22:07
# Name: Время создания, Length: 1251, dtype: object

# %%
type(df['Время создания']) #это уже не df, Это series - что-то по типу массива для хранения одномерных данных (индексы могут быть строкой/числом/идти не по порядку))
# Out:
# pandas.core.series.Series

# %%
df['Время создания'].shape
# Out:
# (1251,)

# %%
df[['ID', 'Время создания']].head(5) #берём 2 столбца и 5 первых строк
# Out:
#            ID       Время создания
# 0  1390015880  2023-05-18 12:59:34
# 1  1388899864  2023-05-17 11:17:08
# 2  1390069042  2023-05-18 13:48:06
# 3  1390274421  2023-05-18 16:56:19
# 4  1389837454  2023-05-18 10:07:04

# %%
df[[ 'Время создания','ID']].head(5) #можем местами поменять
# Out:
#         Время создания          ID
# 0  2023-05-18 12:59:34  1390015880
# 1  2023-05-17 11:17:08  1388899864
# 2  2023-05-18 13:48:06  1390069042
# 3  2023-05-18 16:56:19  1390274421
# 4  2023-05-18 10:07:04  1389837454

# %%
df.loc[[5, 10, 15],['ID', 'Время создания']] #loc если хотим взять определённые строки и столбцы по названиям колонок и значениям индексов
# Out:
#             ID       Время создания
# 5   1390153681  2023-05-18 15:04:25
# 10  1395673145  2023-05-24 15:59:12
# 15  1403141683  2023-06-01 15:38:16

# %%
df.iloc[[5,10,15], [0, 1]] #iloc если хотим по порядку колонок и порядку значения индексов
# Out:
#             ID       Время создания
# 5   1390153681  2023-05-18 15:04:25
# 10  1395673145  2023-05-24 15:59:12
# 15  1403141683  2023-06-01 15:38:16

# %%
df.iloc[5:11, :3] #типо срезы, берём с 5 по 10 строки и с 0 по 2 столбцы
# Out:
#             ID       Время создания 2. Дата рождения
# 5   1390153681  2023-05-18 15:04:25       1984-07-24
# 6   1391210195  2023-05-19 16:38:12       1977-03-24
# 7   1391045754  2023-05-19 13:54:34       1971-12-27
# 8   1394367994  2023-05-23 12:32:39       1987-04-23
# 9   1395731904  2023-05-24 16:48:21       1994-03-31
# 10  1395673145  2023-05-24 15:59:12       1984-07-12

# %% [markdown]
# фильтр по булевой маске (это типо убрать оди строки, оставить другие)

# %%
df[df['7. Место рождения']=='50 Московская область'] #хотим только Москвичей!
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# 6     1391210195  2023-05-19 16:38:12       1977-03-24   САН24.03.1977
# 9     1395731904  2023-05-24 16:48:21       1994-03-31   СКД31.03.1994
# 14    1397060356  2023-05-25 20:02:26       1972-01-01   ЧАВ01.01.1972
# 15    1403141683  2023-06-01 15:38:16       1967-04-14   БММ14.04.1967
# ...          ...                  ...              ...             ...
# 1218  1625185514  2024-02-14 14:59:34       1984-08-22   НЕИ22.08.1984
# 1219  1625198994  2024-02-14 15:10:43       1986-07-31   ВАВ31.07.1986
# 1241  1639620822  2024-02-28 18:08:02       1996-04-07   СТС07.04.1996
# 1243  1637093134  2024-02-26 12:32:09       1997-09-04   НВН04.09.1997
# 1246  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
#
#       4. Идентификационный номер участника исследования  \
# 4                                              77046139
# ...

# %%
df[df['7. Место рождения'].isin(['50 Московская область', '40 Калужская область'])] #isin если хотим из московской/калужской и тд
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# 6     1391210195  2023-05-19 16:38:12       1977-03-24   САН24.03.1977
# 9     1395731904  2023-05-24 16:48:21       1994-03-31   СКД31.03.1994
# 14    1397060356  2023-05-25 20:02:26       1972-01-01   ЧАВ01.01.1972
# 15    1403141683  2023-06-01 15:38:16       1967-04-14   БММ14.04.1967
# ...          ...                  ...              ...             ...
# 1219  1625198994  2024-02-14 15:10:43       1986-07-31   ВАВ31.07.1986
# 1241  1639620822  2024-02-28 18:08:02       1996-04-07   СТС07.04.1996
# 1243  1637093134  2024-02-26 12:32:09       1997-09-04   НВН04.09.1997
# 1246  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
# 1247  1637052808  2024-02-26 11:53:10       1989-07-11   ЕУИ11.07.1989
#
#       4. Идентификационный номер участника исследования  \
# 4                                              77046139
# ...

# %%
df[(df['7. Место рождения'] == '50 Московская область') | (df['7. Место рождения'] == '50 Московская область')] #=isin (\ -или, & - и), булевая опрерация обязательно в скобках
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# 6     1391210195  2023-05-19 16:38:12       1977-03-24   САН24.03.1977
# 9     1395731904  2023-05-24 16:48:21       1994-03-31   СКД31.03.1994
# 14    1397060356  2023-05-25 20:02:26       1972-01-01   ЧАВ01.01.1972
# 15    1403141683  2023-06-01 15:38:16       1967-04-14   БММ14.04.1967
# ...          ...                  ...              ...             ...
# 1218  1625185514  2024-02-14 14:59:34       1984-08-22   НЕИ22.08.1984
# 1219  1625198994  2024-02-14 15:10:43       1986-07-31   ВАВ31.07.1986
# 1241  1639620822  2024-02-28 18:08:02       1996-04-07   СТС07.04.1996
# 1243  1637093134  2024-02-26 12:32:09       1997-09-04   НВН04.09.1997
# 1246  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
#
#       4. Идентификационный номер участника исследования  \
# 4                                              77046139
# ...

# %%
df['4. Идентификационный номер участника исследования'].notna() 
#булевая штука, есть ли на это месте элемент (хотим отфильтровать пропуски)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1246    True
# 1247    True
# 1248    True
# 1249    True
# 1250    True
# Name: 4. Идентификационный номер участника исследования, Length: 1251, dtype: bool

# %%
df['4. Идентификационный номер участника исследования'].isna().sum() #является ли элемент пустым и считаем пропуски по этому столбцу
# Out:
# np.int64(0)

# %%
df.loc[df['6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / психотическое состояние'].notna(), '3. Код пациента'] 
#код пациентов для которых мы знем инфу в 6 колонке
# Out:
# 4      ЗАА10.10.1996
# 23     ГАВ18.05.1975
# 29      МБШ24.021989
# 68     ИАА03.12.1988
# 84     ЕДД14.07.1992
# 89     ЕМВ19.04.1994
# 90     ЛИИ08.06.1990
# 101    СМП14.08.1985
# 106    ГЮВ04.12.1995
# 110    ФАВ22.02.1991
# 112    МСН20.03.1986
# 115    ФАВ14.03.1996
# 119    ММР15.09.1975
# 128    БАИ28.06.1987
# 165    ВИА22.06.1987
# 166    ДАЕ19.12.1978
# 169    ЛАЕ06.11.1973
# 180    ПАВ10.06.1987
# 187    ЛВГ20.09.1986
# 201    ЕДД10.10.1993
# 211    ВВВ05.11.1958
# 214    КДА08.12.1968
# 220    КПИ08.12.2002
# 246    МАИ21.04.1986
# 285    САВ19.01.2004
# 309    КАА20.03.1998
# 331    ДЕА10.12.2001
# 377    ПИА16.05.1980
# 419    ШПЕ16.10.1989
# 456    КАН18.09.1983
# 498     ХЕЮ12.011990
# 510    ПАО30.04.2003
# 547    КАВ30.07.1992
# 576    ВНС16.01.2003
# 886    ФЕГ24.02.1981
# 887    МРМ18.07.1985
# Name: 3. Код пациента, dtype: object

# %% [markdown]
# Сортировка данных

# %%
df.sort_values('2. Дата рождения').head(10) #отсортировали по дате рождения
# Out:
#              ID       Время создания 2. Дата рождения 3. Код пациента  \
# 530  1799015921  2024-07-31 13:12:49       1948-10-26   ГЮН26.10.1948
# 378  1671415139  2024-03-19 13:54:21       1950-11-17   ЖМВ17.11.1950
# 385  1679813675  2024-03-26 12:19:29       1951-06-09   ВАФ09.06.1951
# 239  1542133699  2023-11-13 11:30:18       1951-08-15   САГ15.08.1951
# 472  1757920168  2024-06-04 14:05:45       1952-02-17   ССН17.02.1952
# 95   1445223593  2023-07-26 11:58:29       1952-04-14   КВМ14.04.1952
# 229  1569412445  2023-12-11 16:22:14       1952-05-26   ФАИ26.05.1952
# 253  1571378928  2023-12-13 11:16:01       1952-07-03   ЗВВ03.07.1952
# 369  1661111756  2024-03-13 11:45:52       1952-08-18   ЕЮС18.08.1952
# 572  1831334434  2024-09-11 16:10:10       1953-08-22   МАВ22.08.1953
#
#      4. Идентификационный номер участника исследования  \
# 530                                           77047174
# 378                                           77046940
# ...

# %%
df.sort_values(['2. Дата рождения', '4. Идентификационный номер участника исследования'], ascending = [False, True]). head(10) #те у кого одинаковый ДР сортируются по номеру. false - от большего к меньшему для ДР. True от меньшего к большему для номера
# Out:
#              ID       Время создания 2. Дата рождения 3. Код пациента  \
# 957  1389261484  2023-05-17 16:46:11       2023-12-22   САМ22.12.2023
# 635  1826164126  2024-09-05 17:29:21       2006-04-10   КСИ10.04.2006
# 637  1859341094  2024-10-09 17:35:58       2006-03-14   ВНВ14.03.2006
# 533  1798911423  2024-07-31 11:04:10       2005-10-14   ВНА14.10.2005
# 607  1525560712  2023-10-27 15:51:36       2005-10-09   ПДА09.10.2005
# 323  1605762448  2024-01-23 15:17:34       2005-07-28   БРЛ28.07.2005
# 346  1632016782  2024-02-20 18:15:54       2005-05-26   ДИС26.05.2005
# 609  1532724469  2023-11-03 15:00:53       2005-05-25   НДМ25.05.2005
# 642  1864747493  2024-10-15 11:39:06       2005-04-07   СЭА07.04.2005
# 648  1877626432  2024-10-28 09:56:22       2005-02-14   ШВИ14.02.2005
#
#      4. Идентификационный номер участника исследования  \
# 957                                           77046112
# 635                                           77047054
# ...

# %% [markdown]
# ура ура как объединять df)))

# %%
df2 = pd.read_excel('rs6295_HTR1A.xlsx')

# %%
df2
# Out:
#        ПАЦИЕНТ Генотип rs6295
# 0     77047007            C/C
# 1     77046881            C/C
# 2     77046884            C/C
# 3     77046888            C/C
# 4     77046963            C/C
# ...        ...            ...
# 1040  77046906            G/C
# 1041  77046907            C/C
# 1042  77046908            G/C
# 1043  77046909            C/C
# 1044  77047002            G/G
#
# [1045 rows x 2 columns]

# %%
cdf1 = pd.concat([df, df2]) #1 способ: конкатенация по строкам - те же колонки, но строк больше

# %%
cdf1
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0     1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1     1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2     1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
# 3     1390274421  2023-05-18 16:56:19       1969-10-17   СВН17.10.1969
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# ...          ...                  ...              ...             ...
# 1040         NaN                  NaN              NaN             NaN
# 1041         NaN                  NaN              NaN             NaN
# 1042         NaN                  NaN              NaN             NaN
# 1043         NaN                  NaN              NaN             NaN
# 1044         NaN                  NaN              NaN             NaN
#
#       4. Идентификационный номер участника исследования  \
# 0                                            77046135.0
# ...

# %%
cdf2 = pd.concat([df, df2], axis = 1) #конкатенация по столбцам - axis 1

# %%
cdf2
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0     1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1     1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2     1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
# 3     1390274421  2023-05-18 16:56:19       1969-10-17   СВН17.10.1969
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# ...          ...                  ...              ...             ...
# 1246  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
# 1247  1637052808  2024-02-26 11:53:10       1989-07-11   ЕУИ11.07.1989
# 1248  1637047529  2024-02-26 11:47:56       1997-05-21   ВЕА01.05.1997
# 1249  1857808898  2024-10-08 10:25:37       1993-12-08   ГТГ08.12.1993
# 1250  1882566725  2024-11-01 13:22:07       1994-08-21   ПСИ21.08.1994
#
#       4. Идентификационный номер участника исследования  \
# 0                                              77046135
# ...

# %%
df2 = pd.read_excel('rs6295_HTR1A.xlsx', dtype = {'ПАЦИЕНТ':'Int64'} ) #при простом импорте все значиения из-за NaN записались как float и были нули после ID пациента
#чтобы убрать нули я перевела столбец 'пациент' в целые числа

# %%
df2
# Out:
#        ПАЦИЕНТ Генотип rs6295
# 0     77047007            C/C
# 1     77046881            C/C
# 2     77046884            C/C
# 3     77046888            C/C
# 4     77046963            C/C
# ...        ...            ...
# 1040  77046906            G/C
# 1041  77046907            C/C
# 1042  77046908            G/C
# 1043  77046909            C/C
# 1044  77047002            G/G
#
# [1045 rows x 2 columns]

# %%
new = pd.merge(df, df2, left_on = '4. Идентификационный номер участника исследования', right_on = 'ПАЦИЕНТ', how = 'left') 
#У кого стоит NaN - их нет во второй таблице, если нужны только те, кто есть пишем 'inner'

# %%
new
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0     1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1     1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2     1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
# 3     1390274421  2023-05-18 16:56:19       1969-10-17   СВН17.10.1969
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# ...          ...                  ...              ...             ...
# 1251  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
# 1252  1637052808  2024-02-26 11:53:10       1989-07-11   ЕУИ11.07.1989
# 1253  1637047529  2024-02-26 11:47:56       1997-05-21   ВЕА01.05.1997
# 1254  1857808898  2024-10-08 10:25:37       1993-12-08   ГТГ08.12.1993
# 1255  1882566725  2024-11-01 13:22:07       1994-08-21   ПСИ21.08.1994
#
#       4. Идентификационный номер участника исследования  \
# 0                                              77046135
# ...

# %%
new_fill = pd.merge(df, df2, left_on = '4. Идентификационный номер участника исследования', right_on = 'ПАЦИЕНТ', how = 'inner')
#таблица только с теми, у кого есть данные и в df и в df2

# %%
new_fill
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0     1395764413  2023-05-24 17:17:21       2000-04-18   АИВ18.04.2000
# 1     1403141683  2023-06-01 15:38:16       1967-04-14   БММ14.04.1967
# 2     1403916863  2023-06-02 13:06:12       1986-08-06   МВЮ06.08.1986
# 3     1403813607  2023-06-02 11:14:36       1995-01-11   ГЕА11.01.1995
# 4     1403041965  2023-06-01 13:54:28       1986-01-01   КСВ01.01.2023
# ...          ...                  ...              ...             ...
# 1032  1639620822  2024-02-28 18:08:02       1996-04-07   СТС07.04.1996
# 1033  1637097659  2024-02-26 12:36:23       1999-11-19   ПВМ19.11.1999
# 1034  1637093134  2024-02-26 12:32:09       1997-09-04   НВН04.09.1997
# 1035  1637063129  2024-02-26 12:03:17       1997-01-27   КВО27.01.1997
# 1036  1637047529  2024-02-26 11:47:56       1997-05-21   ВЕА01.05.1997
#
#       4. Идентификационный номер участника исследования  \
# 0                                              77046148
# ...

# %%
new_fill = new_fill.drop('ПАЦИЕНТ', axis = 1)
#удалила столбец в котором одна инфа с столбцом 4

# %%
new_fill.to_excel('C:\\Users\\Vita Rabotinskaya\\jupiter projects\\new_fill2.xlsx')

# %%
new_fill[new_fill['16. Название населенного пункта проживания'].isin(['Коньково', 'Беляево'])]
# Out:
# Empty DataFrame
# ...

# %%
new.count() #считаем количество ненулевых элементов во всём df
# Out:
# ID                                                                                                                                            1256
# Время создания                                                                                                                                1256
# 2. Дата рождения                                                                                                                              1256
# 3. Код пациента                                                                                                                               1256
# 4. Идентификационный номер участника исследования                                                                                             1256
#                                                                                                                                               ...
# ...

# %%
new['2. Дата рождения'].count()
# Out:
# np.int64(1256)

# %%
new['Сколько сигарет (электронных сигарет) участник выкуривает в день?'].mean(), new['Сколько сигарет (электронных сигарет) участник выкуривает в день?'].median()
# среднее и медиана для количества сигарет
# Out:
# (np.float64(15.814863102998697), 15.0)

# %%
new['Сколько сигарет (электронных сигарет) участник выкуривает в день?'].describe()
#ср значение, медиана (50%), квантиль 25 и 75
# Out:
# count    767.000000
# mean      15.814863
# std        8.806575
# min        0.000000
# 25%       10.000000
# 50%       15.000000
# 75%       20.000000
# max       60.000000
# Name: Сколько сигарет (электронных сигарет) участник выкуривает в день?, dtype: float64

# %%
new.groupby('9. Пол')['Сколько сигарет (электронных сигарет) участник выкуривает в день?'].mean() 
#groupby выбираем колонку по которой группируем и ищем среднее по 2 показателю (сколько в среднем сигарет выкуривают женщины и мужчины
# Out:
# 9. Пол
# Женский    13.254335
# Мужской    16.560606
# Name: Сколько сигарет (электронных сигарет) участник выкуривает в день?, dtype: float64

# %%
new.groupby('9. Пол')['Сколько сигарет (электронных сигарет) участник выкуривает в день?'].describe()
# Out:
#          count       mean       std  min   25%   50%   75%   max
# 9. Пол
# Женский  173.0  13.254335  7.054114  1.0  10.0  12.0  20.0  40.0
# Мужской  594.0  16.560606  9.125721  0.0  10.0  18.0  20.0  60.0

# %%
new.groupby(['9. Пол', 'Генотип rs6295'])['Сколько сигарет (электронных сигарет) участник выкуривает в день?'].agg(['mean','median'])
#если хотим что-то конкретное а не всё сразу, как в describe, то agg()
# Out:
#                              mean  median
# 9. Пол  Генотип rs6295
# Женский C/C             13.687500    13.5
#         G/C             13.352941    12.0
#         G/G             13.289474    15.0
# Мужской C/C             16.671756    15.0
#         G/C             15.923767    15.0
#         G/G             16.798387    20.0

# %%
new['Генотип rs6295'].value_counts()
# Out:
# Генотип rs6295
# G/C    483
# G/G    288
# C/C    266
# Name: count, dtype: int64

# %%
new.groupby('Генотип rs6295')['Генотип rs6295'].count()
#то же самое короче
# Out:
# Генотип rs6295
# C/C    266
# G/C    483
# G/G    288
# Name: Генотип rs6295, dtype: int64

# %%
new[['11, Размер обуви', '13. Рост']].corr() 
#ищет корреляцию
#можно и к целому new применить, но у меня не везде числа, поэтому так 
#[[]]!!!! тк [] возвращают столбец, а [[]] data frame
# Out:
#                   11, Размер обуви  13. Рост
# 11, Размер обуви          1.000000  0.136866
# 13. Рост                  0.136866  1.000000

# %%
new['11, Размер обуви'].corr(new['13. Рост'])
# Out:
# np.float64(0.1368661716299059)

# %% [markdown]
# визуализация

# %%
new['11, Размер обуви'].plot(kind = 'hist', bins = 20)
# построили гистограмму kind = 'hist'
# bins - количество столбцов (можно не указывать, если устраивает то, что поумолчанию)
# Out:
# <Axes: ylabel='Frequency'>

# %%
new['11, Размер обуви'].plot(kind = 'kde', xlim=[36,45])
#смотрим распределние, xlim опционально можно указать рамки размера обуви
# Out:
# <Axes: ylabel='Density'>

# %%
new.groupby('Генотип rs6295')['11, Размер обуви'].plot(kind = 'kde', legend = True)
#группируем людей на группы по генотипу и смотрим распределение размера обуви в каждой группе
#legend = True - подписать какой цвет какому генотипу соответствует
# Out:
# Генотип rs6295
# C/C    Axes(0.125,0.11;0.775x0.77)
# G/C    Axes(0.125,0.11;0.775x0.77)
# G/G    Axes(0.125,0.11;0.775x0.77)
# Name: 11, Размер обуви, dtype: object

# %% [markdown]
# как изменять данные

# %%
new_copy = new.copy(deep = True)

# %%
new_copy['11, Размер обуви'] = 355
#теперь у всех размер обуви 355))

# %%
new_copy['11, Размер обуви'].value_counts()
# Out:
# 11, Размер обуви
# 355    1256
# Name: count, dtype: int64

# %%
new = pd.merge(df, df2, left_on ='4. Идентификационный номер участника исследования', right_on = 'ПАЦИЕНТ', how = 'left')

# %%
new = new.drop('ПАЦИЕНТ', axis = 1)

# %%
new['высокий'] = (new['13. Рост'] >= 170)
#новая колонка возвращает булевое значение (высокий или нет) по заданному критерию

# %%
new
# Out:
#               ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0     1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1     1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2     1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
# 3     1390274421  2023-05-18 16:56:19       1969-10-17   СВН17.10.1969
# 4     1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
# ...          ...                  ...              ...             ...
# 1251  1637058068  2024-02-26 11:58:22       1998-12-04   КНИ04.12.1998
# 1252  1637052808  2024-02-26 11:53:10       1989-07-11   ЕУИ11.07.1989
# 1253  1637047529  2024-02-26 11:47:56       1997-05-21   ВЕА01.05.1997
# 1254  1857808898  2024-10-08 10:25:37       1993-12-08   ГТГ08.12.1993
# 1255  1882566725  2024-11-01 13:22:07       1994-08-21   ПСИ21.08.1994
#
#       4. Идентификационный номер участника исследования  \
# 0                                              77046135
# ...

# %%
new['высокая женщина'] = new['высокий'] 
new.loc[new['9. Пол'] == 'Мужской', 'высокая женщина'] = False

#хотим сделать столбец, где будет True/False (высокая женщина)- по 2 критериям 
#1)создаём столбец 'высокая женщина' и кладём значения из столбца 'высокий'
#2) loc - возьми все строки из столбца '9. Пол' со значением 'Мужской' и столбец 'высокая женщина'. Все ячейки из получившейся таблицы сделай  False

# %%
new.loc[new['высокая женщина'] == True, ['высокая женщина']]. head(10)
# Out:
#      высокая женщина
# 45              True
# 57              True
# 69              True
# 89              True
# 92              True
# 96              True
# 107             True
# 142             True
# 143             True
# 150             True

# %%
new.rename(
    columns = {'Генотип rs6295': 'rs6295'}
).head(1)

#переименовываем колонки
# Out:
#            ID       Время создания 2. Дата рождения 3. Код пациента  \
# 0  1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
#
#    4. Идентификационный номер участника исследования  \
# 0                                           77046135
#
#   5. Дата приема участника исследования  \
# 0                            2023-05-18
#
#   6. Дата подписания информированного согласия     7. Место рождения  \
# 0                                   2023-05-17  24 Красноярский край
#
#   8. Место рождения (населенный пункт)   9. Пол  ...  \
# 0                             Норильск  Мужской  ...
#
#   6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / абстинентное стояние с делирием  \
# 0                                                NaN
#
#    6. Другие расстройства, вызванные употреблением алкоголя и/или ПАВ (в анамнезе) / амнестический синдром  \
# 0                                                NaN
#
# ...

# %%
new_lower = new.rename(columns = str.lower)

#все колонки с маленькой буквы

# %%
new_lower['8. МЕСТО РОЖДЕНИЯ'] = new_lower['8. место рождения (населенный пункт)'].apply(lambda x: x.upper())
#добавляем новый столбец, где к каждому значению столбца 8 применяем upper()

# %%
new_lower.head(5)
# Out:
#            id       время создания 2. дата рождения 3. код пациента  \
# 0  1390015880  2023-05-18 12:59:34       1971-08-03   КЮН03.08.1971
# 1  1388899864  2023-05-17 11:17:08       1992-04-21   МЕА21.04.1992
# 2  1390069042  2023-05-18 13:48:06       1986-07-13   ДДВ13.07.1986
# 3  1390274421  2023-05-18 16:56:19       1969-10-17   СВН17.10.1969
# 4  1389837454  2023-05-18 10:07:04       1996-10-10   ЗАА10.10.1996
#
#    4. идентификационный номер участника исследования  \
# 0                                           77046135
# 1                                           77046136
# 2                                           77046137
# 3                                           77046138
# 4                                           77046139
#
#   5. дата приема участника исследования  \
# 0                            2023-05-18
# 1                            2023-05-17
# 2                            2023-05-18
# 3                            2023-05-18
# ...

# %%
('')
